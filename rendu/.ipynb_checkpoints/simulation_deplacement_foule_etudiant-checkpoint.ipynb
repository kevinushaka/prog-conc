# %% [markdown]
# # Simulation de déplacement d'une foule
#
# __NOMS PRENOMS et emails des membres du groupe

# %% [markdown]
# ## Introduction
# <span style="color:red">Mettre ici votre description du projet.</span>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Bibliothèque-Python-pour-le-multi-flots-d'exécution." data-toc-modified-id="Bibliothèque-Python-pour-le-multi-flots-d'exécution.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Bibliothèque Python pour le multi-flots d'exécution.</a></span></li><li><span><a href="#Les-mécanismes-de-synchronisation-en-Python" data-toc-modified-id="Les-mécanismes-de-synchronisation-en-Python-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Les mécanismes de synchronisation en Python</a></span></li><li><span><a href="#Définitions-de-quelques-procédures-pour-initialiser-une-grille-à-partir-d'un-fichier-de-configuration" data-toc-modified-id="Définitions-de-quelques-procédures-pour-initialiser-une-grille-à-partir-d'un-fichier-de-configuration-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Définitions de quelques procédures pour initialiser une grille à partir d'un fichier de configuration</a></span><ul class="toc-item"><li><span><a href="#Définition-de-la-grille" data-toc-modified-id="Définition-de-la-grille-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Définition de la grille</a></span></li><li><span><a href="#Définition-d'un-obstacle" data-toc-modified-id="Définition-d'un-obstacle-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Définition d'un obstacle</a></span></li><li><span><a href="#Définition-d'une-personne" data-toc-modified-id="Définition-d'une-personne-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Définition d'une personne</a></span></li><li><span><a href="#Construction-d'une-image-pour-OpenCV" data-toc-modified-id="Construction-d'une-image-pour-OpenCV-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Construction d'une image pour OpenCV</a></span></li></ul></li><li><span><a href="#Solution-itérative" data-toc-modified-id="Solution-itérative-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Solution itérative</a></span><ul class="toc-item"><li><span><a href="#Avec-trace-mais-sans-visualisation" data-toc-modified-id="Avec-trace-mais-sans-visualisation-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Avec trace mais sans visualisation</a></span></li><li><span><a href="#Visualisation-de-chacune-des-itérations-avec-Matplotlib" data-toc-modified-id="Visualisation-de-chacune-des-itérations-avec-Matplotlib-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Visualisation de chacune des itérations avec Matplotlib</a></span></li><li><span><a href="#Visualisation-de-chacune-des-itérations-avec-OpenCV" data-toc-modified-id="Visualisation-de-chacune-des-itérations-avec-OpenCV-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Visualisation de chacune des itérations avec OpenCV</a></span></li><li><span><a href="#Sans-trace-mais-avec-visualisation" data-toc-modified-id="Sans-trace-mais-avec-visualisation-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Sans trace mais avec visualisation</a></span></li><li><span><a href="#Utilisation-des-procédures-précédentes-pour-créer-une-nouvelle-grille-qui-sera-sauvegardée-dans-un-fichier" data-toc-modified-id="Utilisation-des-procédures-précédentes-pour-créer-une-nouvelle-grille-qui-sera-sauvegardée-dans-un-fichier-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Utilisation des procédures précédentes pour créer une nouvelle grille qui sera sauvegardée dans un fichier</a></span></li></ul></li><li><span><a href="#Votre-travail" data-toc-modified-id="Votre-travail-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><span style="color: red">Votre travail</span></a></span></li><li><span><a href="#Scénario-1" data-toc-modified-id="Scénario-1-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Scénario 1</a></span></li><li><span><a href="#Scénario-2" data-toc-modified-id="Scénario-2-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Scénario 2</a></span></li><li><span><a href="#Scénario-3" data-toc-modified-id="Scénario-3-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Scénario 3</a></span></li><li><span><a href="#Comparaison-des-trois-approches" data-toc-modified-id="Comparaison-des-trois-approches-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Comparaison des trois approches</a></span></li><li><span><a href="#Export-du-notebook-dans-un-fichier-python" data-toc-modified-id="Export-du-notebook-dans-un-fichier-python-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Export du notebook dans un fichier python</a></span></li></ul></div>

# %% [markdown]
# ## Bibliothèque Python pour le multi-flots d'exécution.
#
# <span style="color:red">Dans cette section vous présenterez votre étude comparative, avec exemple, des bibliothèques python permettant d'exécuter plusieurs flots en parallèle</span>
#
# <span style="color:red">Vous préciserez de manière justifiée à la fin de cette section la bibliothèque choisie. La cellule suivante, exécutable comprendra l'import de la bibliothèque.</span>

# %% [markdown]
# ## Les mécanismes de synchronisation en Python
#
# <span style="color:red">Dans cette section vous présenterez votre étude comparative, avec exemple, des mécanimes présent dans la bibliothèque ou pouvant être associé pour construire une section critique ou permettant de contrôler l'accès à des ressources critiques.
#
# <span style="color:red">Vous préciserez de manière justifiée à la fin de cette section les mécanismes choisis. La cellule suivante, exécutable comprendra l'import des bibliothèques.</span>

# %% [markdown]
# ## Définitions de quelques procédures pour initialiser une grille à partir d'un fichier de configuration
#
# <span style="color:red">Vous ne pouvez pas modifier les classes/procédures/fonctions suivantes</span>

# %%
def is_running_from_ipython():
    # Renvoie True si on execute le code depuis un notebook
       from IPython import get_ipython
       return get_ipython() is not None
is_running_from_ipython()
# Permet de savoir qui exécute le code
import platform
MICHEL = ('michel' in platform.node()) or ('charvin' in platform.node())

# %%
class Debug:
    def __init__(self, debug=False):
        self.debug = debug
        
    def affiche(self, *args):
        if self.debug:
            print(args)

# %%
# Différents imports
import copy
import math
import time
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Reglage de l'affichage

# Définition des affichage possible définition
# !echo 'Aucun = 0' >affichage.py
# !echo 'tkinter = 1' >>affichage.py # Not implemented
# !echo 'OpenCV = 2' >> affichage.py # Not completly implemented

# !echo 'PERSONNE = (0.0, 0.0, 1.0)' >>affichage.py
# !echo 'IMMOBILE = (1.0, 0.0, 0.0)' >>affichage.py
# !echo 'OBSTACLE = (0.0, 1.0, 0.0)' >>affichage.py
# !echo 'EMPTY = (1.0, 1.0, 1.0)' >>affichage.py
# !echo 'ARRIVEE = (0.0, 0.0, 0.0)' >>affichage.py # Not used

import affichage
import cv2

UI = affichage.OpenCV

# %%
#if MICHEL:
petite_grille = "maps/map-initial.txt" # fichier décrivant une petite grille
grande_grille = "maps/map-final.txt"  # fichier décrivant une grande grille
debug = Debug(True)

# %%
# Constant définition
# !echo 'EMPTY = 0' >const.py
# !echo 'OBSTACLE = 1' >>const.py
# !echo 'PERSONNE = 2' >> const.py
# !echo 'IMMOBILE = 3' >> const.py
# !echo 'ARRIVEE = 4' >> const.py
import const

# %%
# Lecture du fichier de configuration
def open_file(filename, debug):
    debug.affiche("Ouverture du fichier", filename)
    fileMap = open(filename, 'r')
    return fileMap

file = open_file(petite_grille, debug)
# Out:
# ('Ouverture du fichier', 'maps/map-initial.txt')

# %% [markdown]
# ### Définition de la grille

# %%
def read_grid_size(file, debug):
    line = file.readline()
    while line[0]=='#':	# on saute les commentaires
        line = file.readline()
    
    # Lecture de la taille de la grille
    while line[0]!='#':	# on lit jusqu'au prochain commentaires
        if (line[0]=='X'):
            X = int(line.split(' ')[1])
        if (line[0]=='Y'):
            Y = int(line.split(' ')[1])
        line = file.readline()

    debug.affiche("Simulation pour une grille:", X, "*", Y)
    
    return X, Y

# %%
X, Y = read_grid_size(file, debug)
# Out:
# ('Simulation pour une grille:', 10, '*', 10)

# %%
# Definition de la grille
class Grille:
    # Crée un objet list
    def __init__(self, Xmax, Ymax, UI, debug):
        debug.affiche("Initilisation de l'objet grille")
        self.Xmax = Xmax
        self.Ymax = Ymax
        if const.EMPTY==0:
            self.map = np.zeros((Xmax, Ymax))
        elif const.EMPTY==1:
            self.map = np.ones((Xmax, Ymax))
        else:
            self.map = np.array(Xmax, Ymax)
            for i in range(Xmax):
                for j in range(Ymax):
                    self.map[i,j] = const.EMPTY
        self.mapList = []
        self.obstacleList = []
        self.personneList = []
        self.debug = debug
        self.UI = UI

    def SetObstacle(self, obstacle):
        for x in range(obstacle.Xmin, obstacle.Xmax+1):
            for y in range(obstacle.Ymin, obstacle.Ymax+1):
                self.map[x][y] = const.OBSTACLE
        self.obstacleList += [obstacle]

    def SetPersonne(self, personne):
        if self.map[personne.X][personne.Y]==const.EMPTY:
            # la case est vide
            self.map[personne.X][personne.Y] = const.PERSONNE
            self.personneList += [personne]
            return True
        else:
            debug.affiche("Personne non créée, la place est occupée", personne.X, personne.Y)
            return False
        
    def isCellEmpty(self, x, y):
        return self.map[x][y]==const.EMPTY
    
    def Set(self, x, y, status):
        self.map[x][y] = status
        
    def Save(self, name):
        with open(name, 'w') as file:
            file.write("# taille de la grille\n")
            file.write("X "+str(self.Xmax)+"\n")
            file.write("Y "+str(self.Ymax)+"\n")
            file.write("# position des obstacles\n")
            file.write("# Xmin Xmax Ymin Ymax\n")
            file.write("# si pas obstacle : mettre -1 comme valeur\n")
            file.write("# "+str(len(self.obstacleList))+" obstacles\n")
            for o in self.obstacleList:
                file.write(str(o.Xmin)+" "+str(o.Xmax)+" "+str(o.Ymin)+" "+str(o.Ymax)+"\n")
            file.write("# position initiale des personnes (X, Y) et case de sortie (X, Y)\n")
            file.write("# "+str(len(self.personneList))+" personnes\n")
            for p in self.personneList:
                file.write(str(p.X)+" "+str(p.Y)+" "+str(p.Xsortie)+" "+str(p.Ysortie)+"\n")
                
    # Solution imparfaite car une personne peut être bloquée par un obstacle
    def Simulation(self):
        if self.debug.debug or self.UI==affichage.OpenCV:
            self.mapList.append(copy.copy(self.map))
        if self.UI==affichage.OpenCV:
            cv2.imshow("img", createImage(self.map))
            cv2.waitKey(500)
    
        while len(self.personneList)>0: # il y a encore une personne dans la liste qui peut bouger
            for personne in self.personneList:
                end, immobile = personne.deplacePersonne(self, self.debug)
                if end:
                    self.debug.affiche("Une personne vient de sortir, il reste", len(self.personneList), "personnes")
            if self.debug.debug or self.UI==affichage.OpenCV:
                self.mapList.append(copy.copy(self.map))
                if self.UI==affichage.OpenCV:
                    cv2.imshow("img", createImage(self.map))
                    cv2.waitKey(500)
    
        if self.UI==affichage.OpenCV:
            cv2.destroyAllWindows()

# %%
# Creation de la grille
grid = Grille(X, Y, affichage.Aucun, debug)
# Out:
# ("Initilisation de l'objet grille",)

# %% [markdown]
# ### Définition d'un obstacle

# %%
class Obstacle():
    def __init__(self, grid,  Xmin, Xmax, Ymin, Ymax, debug):
        self.Xmin = Xmin
        self.Xmax = Xmax
        self.Ymin = Ymin
        self.Ymax = Ymax
        self.debug = debug
        grid.SetObstacle(self)
        debug.affiche("Création de l'obstacle (", Xmin, Xmax, ") - (", Ymin, Ymax, ")")

# %%
def read_obstacles(file, grid, Obstacle, debug):
    # Lecture de la liste des obstacles et placement sur la grille
    line = file.readline()
    while line[0]=='#':	# on saute les commentaires
        line = file.readline()

    while line[0]!='#':	# on lit jusqu'au prochain commentaires
        coordonnee = line.strip().split(' ')
        if int(coordonnee[0])>=0:
            assert (int(coordonnee[0])>0 and int(coordonnee[2])>0)
            assert (int(coordonnee[1])<X)
            assert (int(coordonnee[3])<Y)
            Obstacle(grid, int(coordonnee[0]), int(coordonnee[1]), int(coordonnee[2]), int(coordonnee[3]), debug)
        else:
            debug.affiche("obstacle non créé", coordonnee)
        line = file.readline()        

    debug.affiche(len(grid.obstacleList), "obstacles ont été créés")

# %%
# On lit tous les obstacles contenus dans le fichier de configuration
read_obstacles(file, grid, Obstacle, debug)
# Out:
# ('obstacle non créé', ['-1', '-1', '-1', '-1'])
# ("Création de l'obstacle (", 1, 1, ') - (', 2, 7, ')')
# ("Création de l'obstacle (", 1, 7, ') - (', 8, 8, ')')
# (2, 'obstacles ont été créés')

# %%
# Affichage de la grille
plt.imshow(grid.map, cmap='Paired', vmin=0, vmax=5)
plt.show()

# %% [markdown]
# ### Définition d'une personne

# %%
def distance(X, Y):
    return int(np.abs(X[0]-Y[0])+np.abs(X[1]-Y[1]))

class Personne():
    def __init__(self, grid, Xinit, Yinit, Xsortie, Ysortie, debug):
        self.X = Xinit
        self.Y = Yinit
        self.Xsortie = Xsortie
        self.Ysortie = Ysortie
        self.debug = debug
        personneCrée = grid.SetPersonne(self)
        if personneCrée:
            debug.affiche("Création de la personne qui part de", Xinit, Yinit, "pour aller à", Xsortie, Ysortie)
    
    def getAvailableMove(self, grid): # retourne la liste triée des déplacements possibles
        # distance à la grille
        dist_actuel = distance((self.X, self.Y), (self.Xsortie, self.Ysortie))
        depl = []
        # on calcule la distance entre les case adjacente et la sortie
        for x in range(self.X-1, self.X+2):
            for y in range (self.Y-1, self.Y+2):
                if (x!=self.X or y!=self.Y) and (x==self.X or y==self.Y) and (x>=0 and y>=0 and x<grid.Xmax and y<grid.Ymax): # deplacement uniquement points cardinaux
                    # on est sur une case adjacente et on est sur la grille
                    if grid.isCellEmpty(x, y): # si la case est vide
                        dist = distance((self.Xsortie, self.Ysortie), (x,y))
                        if (dist<dist_actuel): # on se rappproche
                             depl.append((dist, x, y))
        return sorted(depl)

    def getBetterMove(self, grid):
        return self.getAvailableMove(grid)[0]

    def Move(self, grid, depl):
        debug.affiche("Déplacement de la personne de (", self.X, self.Y, ") à (", depl[1], depl[2], ")")
        grid.Set(self.X, self.Y, const.EMPTY)
        self.X = depl[1]
        self.Y = depl[2]
        grid.Set(self.X, self.Y, const.PERSONNE)
        
    def deplacePersonne(self, grid, debug):
        if self.X==self.Xsortie and self.Y==self.Ysortie:
            # la personne est arrivée à la sortie
            # on retire la personne de la liste
            grid.personneList.remove(self)
            # on libere la case de sortie
            grid.Set(self.X, self.Y, const.EMPTY)
            return True, False
    
        # sinon on recherche les déplacements possibles
        availableMove = self.getAvailableMove(grid)
        debug.affiche("La personne (", self.X, self.Y, ") peut se déplacer sur :", availableMove)
            
        if len(availableMove)>0:
            # on se déplace sure la nouvelle case
            self.Move(grid, availableMove[0]) 
            return False, False
        
        # sinon aucun d"éplacement n'est possible
        if grid.UI==affichage.OpenCV:
            grid.Set(self.X, self.Y, const.IMMOBILE)
        debug.affiche("La personne (", self.X, self.Y, "ne peut pas se déplacer")
        return False, True

# %%
def read_personnes(file, grid, Personne, nombre, debug):
    # Lecture de la liste des personnes et placement sur la grille
    # s'arrête quand le nombre de personnes souhaité est atteind
    # Si nombre = -1, on lit jusqu'à la fin du fichier (idem si nombre est supérieur aux nombres de personnes dans le fichier)
    line = file.readline()
    while line[0]=='#':	# on saute les commentaires
        line = file.readline()
        
    while line:	# on lit jusqu'à la fin du fichier
        coordonnee = line.strip().split(' ')
        if coordonnee[0]!='#':
            assert (int(coordonnee[0])>0 and int(coordonnee[1])>0
                and int(coordonnee[2])<X or int(coordonnee[3])<Y) # La personne est sur la grille
            assert ((int(coordonnee[2])==0 or int(coordonnee[2])==X-1)  # elle sort sur un bord X
                and                                                  # et
                (int(coordonnee[3])==0 or int(coordonnee[3])==Y-1)) # elle sort sur un bord Y
            Personne(grid, int(coordonnee[0]), int(coordonnee[1]), int(coordonnee[2]), int(coordonnee[3]), debug)
            
        if len(grid.personneList)==nombre:
            debug.affiche(len(grid.personneList), "personnes ont été créées")
            file.close()
            return
        line = file.readline()
    debug.affiche("Fermeture du fichier")
    file.close()
    
    debug.affiche("On a lut tout le fichier,", len(grid.personneList), "personnes ont été créées")

# %%
# On lit toutes les personnes contenues dans le fichier de configuration
read_personnes(file, grid, Personne, -1, debug)
# Out:
# ('Création de la personne qui part de', 2, 2, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 3, 3, 'pour aller à', 0, 9)
# ('Création de la personne qui part de', 6, 6, 'pour aller à', 9, 0)
# ('Création de la personne qui part de', 7, 7, 'pour aller à', 9, 9)
# ('Fermeture du fichier',)
# ('On a lut tout le fichier,', 4, 'personnes ont été créées')

# %%
# Affichage de la grille
plt.imshow(grid.map, cmap='Paired', vmin=0, vmax=5)
plt.show()

# %% [markdown]
# ### Construction d'une image pour OpenCV

# %%
# Uniquement nécessaire pour la visualisation en OpenCV
def createImage(image):
    X = image.shape[0]
    Y = image.shape[1]
    ZOOM = max(min(1024//X, 1024//Y), 1)
    img = np.zeros((X*ZOOM, Y*ZOOM, 3), dtype=np.float)
    for i in range(X):
        for t in range(ZOOM):
            for j in range(Y):
                for u in range(ZOOM):
                    if image[i][j]==const.EMPTY:
                        img[ZOOM*i+t][ZOOM*j+u]=affichage.EMPTY
                    elif image[i][j]==const.OBSTACLE:
                        img[ZOOM*i+t][ZOOM*j+u]=affichage.OBSTACLE
                    elif image[i][j]==const.PERSONNE:
                        img[ZOOM*i+t][ZOOM*j+u]=affichage.PERSONNE
                    elif image[i][j]==const.IMMOBILE:
                        img[ZOOM*i+t][ZOOM*j+u]=affichage.IMMOBILE
                    elif image[i][j]==const.ARRIVEE:  
                        img[ZOOM*i+t][ZOOM*j+u]=affichage.ARRIVEE
    return img

# %%
# Affichage en OpenCV de la grille créée
if UI==affichage.OpenCV:
    cv2.imshow("img", createImage(grid.map))
    cv2.waitKey(5000) # Affichage pendant 5 secondes
    cv2.destroyAllWindows()

# %% [markdown]
# ## Utilisation des procédures précédentes pour créer une nouvelle grille qui sera sauvegardée dans un fichier

# %%
# Création d'une grille de 1024*1024
debug = Debug(True)
UI = affichage.Aucun

X = 1024
Y = 1024
grid = Grille(X, Y, UI, debug)
# Out:
# ("Initilisation de l'objet grille",)

# %%
# La grille contient 2^4 obstacles
nb_obs = np.power(2,4)

coordonnee = np.zeros((4,1), dtype=np.int)
for i in range(nb_obs):
    for j in range(4):
        val_min = 1+50*i+np.random.randint(10)*10*j
        if j%2 == 0:
            val_max = min(1+val_min+np.random.randint(20), grid.Xmax)
        else:
            val_max = min(1+val_min+np.random.randint(20), grid.Ymax)
        coordonnee[j] = np.random.randint(val_min, val_max)
    
    assert (int(coordonnee[0])>0 and int(coordonnee[2])>0)
    assert (int(coordonnee[1])<X)
    assert (int(coordonnee[3])<Y)
    Obstacle(grid, int(coordonnee[0]), int(coordonnee[1]), int(coordonnee[2]), int(coordonnee[3]), debug)
    
debug.affiche(len(grid.obstacleList), "obstacles ont été créés")
# Out:
# ("Création de l'obstacle (", 5, 93, ') - (', 105, 38, ')')
# ("Création de l'obstacle (", 57, 133, ') - (', 179, 271, ')')
# ("Création de l'obstacle (", 101, 194, ') - (', 282, 381, ')')
# ("Création de l'obstacle (", 163, 249, ') - (', 258, 185, ')')
# ("Création de l'obstacle (", 205, 253, ') - (', 286, 442, ')')
# ("Création de l'obstacle (", 252, 336, ') - (', 420, 439, ')')
# ("Création de l'obstacle (", 310, 313, ') - (', 469, 302, ')')
# ("Création de l'obstacle (", 354, 395, ') - (', 355, 358, ')')
# ("Création de l'obstacle (", 402, 411, ') - (', 445, 588, ')')
# ("Création de l'obstacle (", 461, 453, ') - (', 579, 662, ')')
# ("Création de l'obstacle (", 510, 547, ') - (', 622, 657, ')')
# ("Création de l'obstacle (", 551, 601, ') - (', 617, 611, ')')
# ("Création de l'obstacle (", 610, 642, ') - (', 631, 603, ')')
# ("Création de l'obstacle (", 651, 721, ') - (', 797, 831, ')')
# ("Création de l'obstacle (", 704, 704, ') - (', 837, 955, ')')
# ("Création de l'obstacle (", 759, 775, ') - (', 772, 789, ')')
# (16, 'obstacles ont été créés')

# %%
# La grille contient 2^10 personnes
nb_person = np.power(2,10)

coordonnee = np.zeros((2,1), dtype=np.int)
sortie = np.zeros((2,1), dtype=np.int)
while len(grid.personneList)<nb_person:
    coordonnee[0] = np.random.randint(1,X)
    coordonnee[1] = np.random.randint(1,Y)
    sortie[0] = (X-1)*np.random.randint(2)
    sortie[1] = (Y-1)*np.random.randint(2)
    Personne(grid, int(coordonnee[0]), int(coordonnee[1]), int(sortie[0]), int(sortie[1]), debug)
    
debug.affiche(len(grid.personneList), "personnes ont été créées")
# Out:
# ('Création de la personne qui part de', 634, 15, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 891, 81, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 11, 377, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 948, 644, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 345, 115, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 312, 581, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 126, 76, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 148, 656, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 181, 151, 'pour aller à', 0, 1023)
# ('Personne non créée, la place est occupée', 721, 822)
# ('Création de la personne qui part de', 133, 509, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 614, 57, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 376, 427, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 398, 495, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 539, 435, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 395, 189, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 412, 659, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 931, 660, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 699, 285, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 620, 441, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 876, 124, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 736, 443, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 322, 1000, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 338, 292, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 148, 902, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 283, 706, 'pour aller à', 1023, 1023)
# ('Personne non créée, la place est occupée', 405, 480)
# ('Création de la personne qui part de', 295, 238, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 496, 182, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 326, 608, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 218, 524, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 409, 352, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 1022, 564, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 8, 759, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 892, 423, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 968, 64, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 45, 812, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 530, 148, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 366, 110, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 468, 40, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 589, 796, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 658, 542, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 777, 580, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 271, 191, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 816, 595, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 1017, 79, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 427, 714, 'pour aller à', 1023, 0)
# ('Personne non créée, la place est occupée', 70, 190)
# ('Création de la personne qui part de', 291, 765, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 699, 1004, 'pour aller à', 1023, 0)
# ('Personne non créée, la place est occupée', 138, 282)
# ('Création de la personne qui part de', 953, 458, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 593, 416, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 476, 53, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 252, 947, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 1015, 984, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 413, 801, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 851, 645, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 988, 560, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 768, 925, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 814, 170, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 384, 829, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 943, 47, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 210, 835, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 574, 117, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 934, 523, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 293, 80, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 7, 794, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 252, 275, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 849, 59, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 789, 910, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 363, 233, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 531, 1007, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 773, 954, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 976, 109, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 868, 725, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 530, 228, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 56, 211, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 163, 519, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 1018, 568, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 48, 27, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 741, 76, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 801, 943, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 581, 367, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 672, 914, 'pour aller à', 0, 1023)
# ('Personne non créée, la place est occupée', 181, 359)
# ('Création de la personne qui part de', 348, 748, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 492, 531, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 989, 78, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 581, 181, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 254, 815, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 495, 255, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 114, 938, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 450, 803, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 886, 209, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 773, 1008, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 909, 275, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 961, 187, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 62, 1005, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 541, 469, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 423, 362, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 598, 125, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 292, 907, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 51, 50, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 472, 151, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 127, 149, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 27, 222, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 959, 712, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 392, 376, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 1016, 793, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 35, 880, 'pour aller à', 0, 0)
# ('Personne non créée, la place est occupée', 118, 312)
# ('Création de la personne qui part de', 83, 980, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 437, 763, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 397, 682, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 146, 764, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 826, 704, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 648, 736, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 566, 478, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 937, 618, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 303, 442, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 650, 711, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 465, 416, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 459, 927, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 632, 700, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 43, 688, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 679, 90, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 709, 590, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 16, 76, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 409, 254, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 886, 287, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 411, 402, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 775, 97, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 343, 247, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 456, 428, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 962, 10, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 894, 4, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 217, 916, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 752, 431, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 182, 859, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 949, 808, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 900, 307, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 473, 123, 'pour aller à', 1023, 0)
# ('Personne non créée, la place est occupée', 125, 312)
# ('Création de la personne qui part de', 440, 287, 'pour aller à', 0, 0)
# ('Personne non créée, la place est occupée', 521, 650)
# ('Création de la personne qui part de', 820, 419, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 342, 196, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 540, 771, 'pour aller à', 1023, 1023)
# ('Personne non créée, la place est occupée', 98, 195)
# ('Création de la personne qui part de', 721, 742, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 426, 356, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 701, 2, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 345, 691, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 225, 230, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 836, 178, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 34, 95, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 374, 969, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 466, 436, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 278, 251, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 1017, 69, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 925, 103, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 77, 871, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 223, 858, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 986, 327, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 732, 669, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 751, 829, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 223, 681, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 254, 800, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 315, 783, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 73, 535, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 384, 661, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 638, 383, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 796, 3, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 680, 733, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 669, 754, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 922, 649, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 649, 198, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 8, 164, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 774, 902, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 297, 370, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 465, 209, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 556, 609, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 124, 7, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 288, 584, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 22, 1014, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 890, 626, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 4, 243, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 651, 876, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 852, 945, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 361, 504, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 763, 230, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 954, 225, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 1000, 681, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 188, 868, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 813, 464, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 913, 771, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 626, 1016, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 398, 197, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 192, 205, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 473, 125, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 583, 982, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 799, 129, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 266, 198, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 959, 654, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 877, 240, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 683, 505, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 758, 37, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 628, 846, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 138, 190, 'pour aller à', 0, 1023)
# ('Personne non créée, la place est occupée', 234, 368)
# ('Création de la personne qui part de', 853, 692, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 134, 216, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 310, 151, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 354, 494, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 942, 699, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 233, 946, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 930, 225, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 904, 964, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 684, 720, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 914, 880, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 891, 932, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 867, 333, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 570, 558, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 508, 652, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 445, 309, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 981, 289, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 861, 394, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 136, 278, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 645, 440, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 808, 399, 'pour aller à', 0, 0)
# ('Personne non créée, la place est occupée', 193, 368)
# ('Création de la personne qui part de', 240, 892, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 929, 19, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 430, 333, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 695, 881, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 285, 374, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 462, 659, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 1000, 901, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 110, 543, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 416, 320, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 725, 997, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 675, 43, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 434, 962, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 982, 657, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 606, 343, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 858, 923, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 543, 565, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 1004, 636, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 231, 733, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 756, 1019, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 280, 27, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 868, 290, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 5, 820, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 448, 65, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 86, 603, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 910, 112, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 25, 557, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 869, 1019, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 162, 629, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 277, 54, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 999, 371, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 790, 357, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 231, 13, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 47, 558, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 75, 592, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 946, 704, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 681, 883, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 216, 107, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 895, 715, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 174, 726, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 853, 11, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 5, 809, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 415, 98, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 659, 274, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 596, 768, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 211, 88, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 758, 774, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 558, 703, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 779, 858, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 577, 757, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 575, 274, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 310, 54, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 633, 249, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 221, 17, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 523, 230, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 295, 65, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 486, 287, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 447, 637, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 687, 231, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 592, 515, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 231, 625, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 719, 631, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 919, 227, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 880, 604, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 269, 567, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 20, 498, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 934, 406, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 308, 885, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 559, 401, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 327, 703, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 558, 483, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 980, 246, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 724, 565, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 631, 6, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 615, 945, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 219, 585, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 779, 55, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 803, 21, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 411, 58, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 183, 480, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 199, 578, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 882, 778, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 880, 656, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 906, 68, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 911, 511, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 327, 267, 'pour aller à', 1023, 1023)
# ('Personne non créée, la place est occupée', 87, 181)
# ('Création de la personne qui part de', 542, 698, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 548, 816, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 1000, 444, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 664, 93, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 922, 125, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 554, 907, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 139, 786, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 305, 981, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 827, 609, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 620, 932, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 831, 278, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 588, 163, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 350, 442, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 108, 75, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 845, 456, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 884, 286, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 92, 934, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 744, 875, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 920, 770, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 150, 180, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 969, 571, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 616, 365, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 53, 415, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 577, 794, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 30, 904, 'pour aller à', 0, 1023)
# ('Personne non créée, la place est occupée', 133, 380)
# ('Création de la personne qui part de', 624, 217, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 516, 137, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 320, 905, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 864, 77, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 302, 881, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 360, 6, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 839, 913, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 745, 570, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 998, 674, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 45, 815, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 105, 896, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 405, 376, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 539, 567, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 393, 665, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 351, 41, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 698, 362, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 766, 94, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 19, 592, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 304, 714, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 717, 986, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 451, 1022, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 293, 358, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 698, 337, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 703, 225, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 373, 423, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 940, 709, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 326, 466, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 534, 124, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 664, 974, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 496, 633, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 873, 568, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 932, 918, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 698, 97, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 890, 846, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 101, 758, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 173, 671, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 358, 362, 'pour aller à', 1023, 1023)
# ('Personne non créée, la place est occupée', 205, 438)
# ('Création de la personne qui part de', 157, 612, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 323, 740, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 75, 1014, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 22, 97, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 712, 458, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 928, 359, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 415, 3, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 29, 496, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 882, 777, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 129, 917, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 175, 769, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 746, 712, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 443, 76, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 442, 796, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 261, 1001, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 90, 951, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 810, 859, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 941, 648, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 615, 567, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 885, 815, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 216, 963, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 473, 951, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 406, 64, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 644, 858, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 271, 320, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 684, 589, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 887, 462, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 838, 204, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 400, 1003, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 867, 208, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 581, 560, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 654, 154, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 322, 911, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 665, 213, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 176, 759, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 825, 23, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 1006, 203, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 780, 869, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 638, 859, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 748, 688, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 874, 367, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 339, 39, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 740, 25, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 186, 405, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 301, 97, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 65, 439, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 175, 989, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 771, 546, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 957, 887, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 807, 541, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 773, 453, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 887, 673, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 528, 836, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 530, 163, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 336, 794, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 946, 553, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 135, 72, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 641, 965, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 792, 529, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 284, 205, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 419, 762, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 742, 393, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 6, 137, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 385, 66, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 509, 79, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 634, 857, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 602, 675, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 381, 851, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 810, 284, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 736, 973, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 410, 641, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 374, 426, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 237, 84, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 900, 332, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 180, 90, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 93, 432, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 704, 425, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 530, 988, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 907, 136, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 22, 213, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 503, 50, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 467, 344, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 294, 779, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 339, 998, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 632, 191, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 789, 972, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 358, 463, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 149, 685, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 91, 461, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 638, 510, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 998, 345, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 317, 40, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 648, 596, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 567, 425, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 681, 340, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 985, 754, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 975, 182, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 290, 661, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 509, 789, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 961, 241, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 846, 1013, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 843, 27, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 863, 170, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 172, 619, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 1, 11, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 778, 288, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 116, 30, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 635, 520, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 367, 83, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 903, 670, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 858, 79, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 691, 658, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 649, 326, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 589, 241, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 700, 865, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 64, 754, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 888, 973, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 1001, 495, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 321, 123, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 20, 139, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 702, 779, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 1017, 53, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 143, 799, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 918, 160, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 400, 1016, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 643, 922, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 38, 681, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 391, 750, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 663, 708, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 785, 1014, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 25, 579, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 807, 824, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 1006, 126, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 955, 324, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 702, 938, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 982, 1, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 222, 787, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 400, 29, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 576, 1003, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 657, 319, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 588, 898, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 771, 623, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 6, 843, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 495, 765, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 353, 403, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 271, 123, 'pour aller à', 0, 0)
# ('Personne non créée, la place est occupée', 72, 203)
# ('Création de la personne qui part de', 519, 672, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 935, 312, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 894, 169, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 563, 661, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 571, 783, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 15, 790, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 834, 443, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 261, 843, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 399, 84, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 267, 275, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 866, 133, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 155, 212, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 177, 455, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 271, 247, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 532, 114, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 965, 902, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 55, 575, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 58, 531, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 391, 288, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 702, 432, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 355, 464, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 637, 425, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 851, 615, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 429, 449, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 1022, 622, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 279, 346, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 629, 90, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 531, 883, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 699, 274, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 956, 447, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 456, 429, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 930, 232, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 944, 1011, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 465, 152, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 953, 284, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 987, 528, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 591, 234, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 350, 571, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 413, 402, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 389, 858, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 585, 444, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 610, 44, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 179, 178, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 335, 183, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 370, 697, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 378, 6, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 880, 275, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 339, 573, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 864, 595, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 216, 224, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 824, 403, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 55, 818, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 429, 532, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 992, 188, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 706, 782, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 120, 452, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 879, 607, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 726, 407, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 841, 778, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 686, 949, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 747, 310, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 584, 24, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 1009, 450, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 214, 616, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 951, 984, 'pour aller à', 0, 0)
# ('Personne non créée, la place est occupée', 247, 294)
# ('Création de la personne qui part de', 933, 807, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 661, 955, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 1008, 407, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 297, 50, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 282, 347, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 715, 56, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 834, 249, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 906, 711, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 105, 474, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 1002, 907, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 460, 392, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 357, 685, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 619, 460, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 463, 218, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 789, 13, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 767, 740, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 748, 347, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 263, 983, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 227, 691, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 427, 7, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 617, 696, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 979, 252, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 390, 405, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 403, 602, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 799, 845, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 1000, 467, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 364, 534, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 359, 767, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 663, 69, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 613, 133, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 201, 388, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 761, 310, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 836, 205, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 393, 226, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 966, 861, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 445, 448, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 193, 911, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 135, 651, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 814, 463, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 1002, 812, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 71, 729, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 323, 514, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 127, 67, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 865, 945, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 85, 317, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 789, 209, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 408, 702, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 802, 204, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 505, 803, 'pour aller à', 1023, 1023)
# ...
# ('Création de la personne qui part de', 187, 813, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 371, 131, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 475, 702, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 63, 882, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 759, 122, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 955, 807, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 372, 722, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 153, 394, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 712, 712, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 236, 900, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 201, 66, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 797, 509, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 266, 201, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 964, 28, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 365, 817, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 788, 307, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 1008, 479, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 195, 693, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 590, 138, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 46, 846, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 464, 712, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 63, 624, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 314, 622, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 238, 541, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 231, 143, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 215, 961, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 55, 986, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 537, 983, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 714, 276, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 544, 435, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 67, 797, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 830, 267, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 152, 40, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 536, 871, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 936, 172, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 857, 783, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 224, 228, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 191, 704, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 774, 138, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 675, 511, 'pour aller à', 1023, 1023)
# ('Personne non créée, la place est occupée', 188, 361)
# ('Création de la personne qui part de', 662, 210, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 13, 841, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 505, 461, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 409, 853, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 882, 636, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 937, 262, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 123, 912, 'pour aller à', 0, 0)
# ('Personne non créée, la place est occupée', 238, 406)
# ('Création de la personne qui part de', 55, 307, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 544, 739, 'pour aller à', 1023, 0)
# ('Personne non créée, la place est occupée', 104, 255)
# ('Création de la personne qui part de', 816, 811, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 264, 826, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 661, 843, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 907, 959, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 959, 128, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 624, 6, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 438, 691, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 929, 81, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 458, 664, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 813, 163, 'pour aller à', 1023, 0)
# ('Personne non créée, la place est occupée', 653, 814)
# ('Création de la personne qui part de', 712, 854, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 657, 880, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 239, 825, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 558, 614, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 836, 352, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 248, 490, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 966, 25, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 570, 105, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 962, 586, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 11, 740, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 352, 943, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 947, 821, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 377, 696, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 141, 521, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 501, 432, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 1023, 418, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 149, 402, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 590, 317, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 155, 73, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 326, 783, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 920, 649, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 900, 822, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 562, 451, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 309, 783, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 453, 650, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 645, 363, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 312, 887, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 991, 770, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 627, 504, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 867, 864, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 985, 416, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 287, 738, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 369, 196, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 697, 221, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 984, 589, 'pour aller à', 1023, 1023)
# ('Personne non créée, la place est occupée', 109, 269)
# ('Création de la personne qui part de', 703, 946, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 370, 164, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 454, 734, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 557, 491, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 399, 500, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 200, 541, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 789, 58, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 949, 403, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 764, 322, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 812, 712, 'pour aller à', 0, 0)
# ('Personne non créée, la place est occupée', 236, 355)
# ('Création de la personne qui part de', 983, 349, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 499, 502, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 379, 456, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 995, 837, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 13, 252, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 552, 689, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 305, 959, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 257, 124, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 805, 539, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 957, 73, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 470, 910, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 514, 785, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 461, 18, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 931, 899, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 228, 447, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 669, 1009, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 945, 188, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 277, 796, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 294, 920, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 737, 494, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 364, 632, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 609, 671, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 385, 584, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 534, 34, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 974, 997, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 126, 940, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 659, 342, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 490, 150, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 168, 986, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 379, 673, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 346, 520, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 13, 746, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 292, 301, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 875, 466, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 923, 827, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 894, 268, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 790, 33, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 238, 622, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 657, 840, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 278, 83, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 717, 152, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 289, 339, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 324, 287, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 1, 303, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 167, 802, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 862, 1012, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 359, 781, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 365, 1002, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 794, 503, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 1000, 771, 'pour aller à', 0, 1023)
# ('Personne non créée, la place est occupée', 132, 215)
# ('Création de la personne qui part de', 144, 602, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 613, 641, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 993, 448, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 388, 696, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 277, 1018, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 353, 917, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 461, 937, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 482, 817, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 79, 726, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 977, 459, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 91, 566, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 285, 203, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 747, 288, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 339, 503, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 995, 694, 'pour aller à', 0, 0)
# ('Personne non créée, la place est occupée', 173, 361)
# ('Création de la personne qui part de', 675, 626, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 428, 599, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 460, 211, 'pour aller à', 0, 0)
# ('Personne non créée, la place est occupée', 228, 358)
# ('Création de la personne qui part de', 581, 452, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 191, 490, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 952, 395, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 433, 125, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 911, 540, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 466, 67, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 1004, 976, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 122, 594, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 326, 1015, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 650, 493, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 636, 331, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 357, 350, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 615, 589, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 582, 511, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 842, 196, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 146, 741, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 897, 391, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 725, 1006, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 642, 523, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 386, 336, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 232, 619, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 815, 697, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 817, 698, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 155, 970, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 946, 749, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 638, 169, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 268, 965, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 918, 109, 'pour aller à', 0, 1023)
# ('Création de la personne qui part de', 651, 363, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 537, 685, 'pour aller à', 1023, 0)
# ('Création de la personne qui part de', 867, 341, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 652, 217, 'pour aller à', 1023, 1023)
# ('Création de la personne qui part de', 837, 915, 'pour aller à', 0, 0)
# (1024, 'personnes ont été créées')

# %%
# Sauvegarde de l'objet grille
grid.Save(grande_grille)

# %%
# Affichage de la grille créée
if UI==affichage.OpenCV:
    cv2.imshow("img", createImage(grid.map))
    cv2.waitKey(5000) # Affichage pendant 5 secondes
    cv2.destroyAllWindows()

# %% [markdown]
# ## Solution itérative
#
# Chaque personne doit rejoindre sa case de sortie. Le code est fourni à titre d'exemple. Il est malheureusement incomplet car si une personne ne peut pas rejoindre sa case de sortie alors la simulation ne s'arrête pas.
#
# Si vous avez besoin de modifier les classes proposées. Il suffit de construire par héritage la nouvelle classe qui doit porter le même nom que la classe parente suffixé par \_1 ou \_2 ou \_3 selon l'étape du projet, et de surcharger les méthodes qui doivent l'être.
#
# Les cellules suivantes donnent des exemples d'utilisation des primitives précédemment écrites.

# %% [markdown]
# ### Avec trace mais sans visualisation

# %%
# En mode debug avec 1 personne, sans UI
debug = Debug(True)

file = open_file(petite_grille, debug)  # On ouvre le fichier
X, Y = read_grid_size(file, debug) # On lit la taille
grid = Grille(X, Y, affichage.Aucun, debug)     # On créée l'objet grille
read_obstacles(file, grid, Obstacle, debug)  # On lit et positionne les obstacles
read_personnes(file, grid, Personne, 1, debug) # On lit et positionne une seule personne
print("*"*20)
print("Début de la simulation")
grid.Simulation()
# Out:
# ('Ouverture du fichier', 'maps/map-initial.txt')
# ('Simulation pour une grille:', 10, '*', 10)
# ("Initilisation de l'objet grille",)
# ('obstacle non créé', ['-1', '-1', '-1', '-1'])
# ("Création de l'obstacle (", 1, 1, ') - (', 2, 7, ')')
# ("Création de l'obstacle (", 1, 7, ') - (', 8, 8, ')')
# (2, 'obstacles ont été créés')
# ('Création de la personne qui part de', 2, 2, 'pour aller à', 0, 0)
# (1, 'personnes ont été créées')
# ********************
# Début de la simulation
# ('La personne (', 2, 2, ') peut se déplacer sur :', [(3, 2, 1)])
# ('Déplacement de la personne de (', 2, 2, ') à (', 2, 1, ')')
# ('La personne (', 2, 1, ') peut se déplacer sur :', [(2, 1, 1), (2, 2, 0)])
# ('Déplacement de la personne de (', 2, 1, ') à (', 1, 1, ')')
# ('La personne (', 1, 1, ') peut se déplacer sur :', [(1, 0, 1), (1, 1, 0)])
# ('Déplacement de la personne de (', 1, 1, ') à (', 0, 1, ')')
# ('La personne (', 0, 1, ') peut se déplacer sur :', [(0, 0, 0)])
# ('Déplacement de la personne de (', 0, 1, ') à (', 0, 0, ')')
# ('Une personne vient de sortir, il reste', 0, 'personnes')

# %% [markdown]
# ### Visualisation de chacune des itérations avec Matplotlib

# %%
for img in grid.mapList:
    plt.imshow(img, cmap='Paired', vmin=0, vmax=5)
    plt.show()

# %% [markdown]
# ### Visualisation de chacune des itérations avec OpenCV

# %%
if UI==affichage.OpenCV:
    for image in grid.mapList:
        cv2.imshow("img", createImage(image))
        cv2.waitKey(500) # Wait for 0.5 second
    cv2.destroyAllWindows()

# %% [markdown]
# ### Sans trace mais avec visualisation

# %%
# En mode sans trace avec 1 personne mais avec UI
if UI==affichage.OpenCV:
    debug = Debug(False)
    file = open_file(petite_grille, debug)  # On ouvre le fichier
    X, Y = read_grid_size(file, debug) # On lit la taille
    grid = Grille(X, Y, affichage.OpenCV, debug)     # On créée l'objet grille
    read_obstacles(file, grid, Obstacle, debug)  # On lit et positionne les obstacles
    read_personnes(file, grid, Personne, 1, debug) # On lit et positionne une seule personne
    grid.Simulation()

# %% [markdown]
# ## <span style="color:red">Votre travail</span>
#
# Mettre en oeuvre plusieurs version du simulateur :
# 1. Version itérative : un seul flot d'exécution. Celui-ci est presque terminé, il faut reste à trouver une manière la plus judicieuse possible pour résoudre le problème des personnes bloquées par un obsatacle sans modifier le comportement d'une personne.
# 1. Version un flot d'exécution par personne. Attention a bien protéger par une section critique tout accès à une ressource concurrente que ce soit une trace d'exécution en mode debug ou une ressource partagée. On fera attention a reduire dans la mesure du possible la portée d'une section critique
# 1. Version un flot d'exécution pour un quard de la grille. Une personne de coordonnée X, Y sera gérée par le flot d'exécution numéro $i = 2* (Y//(Ymax//2)) + X//(Xmax//2)$.
#
# Vous construirez ces différentes versions en créant si nécessaire des sous-classes aux classes existantes.

# %% [markdown]
# Bien évidemment, on attend une étude comparative des différentes approches. Pour vous aider dans l'analyse des solutions qui doivent être décrites vous utiliserez un nombre variable de personnes. Pour cela, vous adapterez le code suivant afin de pouvoir mesurer l'évolution du temps d'exécution en fonction du nombre de personnes présentes sur la grille et comparer les temps d'exécution entre les scénarios
# <code>
# debug = Debug(False)
#
# duration_i = []  # i est le numéro du scénario
# nb_personnes = []
# for i in range(11):
#     nb_personnes += [np.power(2, i)]
#     print("*"*30)
#     print("pour", nb_personnes[-1], "personnes")
#
#     file = open_file(grande_grille, debug)  # On ouvre le fichier
#     X, Y = read_grid_size(file, debug) # On lit la taille
#     debug.affiche("simulation pour une grille:", X, Y)
#     grid = Grille(X, Y, debug)     # On créée l'objet grille
#     read_obstacles(file, grid, Obstacle, debug)  # On lit et positionne les obstacles
#     read_personnes(file, grid, Personne, nb_personnes[-1], debug) # On lit et positionne le nombre de personne souhaité seule personne
#     debug.affiche("nbre de personnes", len(grid.personneList))
#
#     start = time.time()
#     grid.Simulation(debug)
#     end = time.time()
#     duration_i += [end-start]
#     print("La simulation a duré", duration1[-1], "secondes")
#     print("Il restait", XXXXX, "personnes immobiles")<code>

# %% [markdown]
# Vous ferez un plot de l'évolution des temps d'exécution
# <code>
# plt.plot(nb_personnes, duration_1, label="Une seule thread")
# plt.plot(nb_personnes, duration_2, label="Une thread par personne")
# plt.plot(nb_personnes, duration_2, label="Une thread par quard de terrain")
# plt.xlabel("nombre de personnes")
# plt.ylabel("temps en secondes")
# plt.legend()
# plt.show()<code>

# %% [markdown]
# Vous calculerez les ratios entre les scénarios
# <code>
# ratio_2 = []
# ratio_3 = []
# for i,j,k in zip(duration_1, duration_2, duration_3):
#     ratio_2 += [j/i]
#     ratio_3 += [k/i]
# plt.plot(nb_personnes, ratio_2, label="...")
# plt.plot(nb_personnes, ratio_3, label="...")
# plt.xlabel("nombre de personnes")
# plt.ylabel("...")
# plt.legend()
# plt.show()<code>

# %% [markdown]
# Vous calculerez aussi le speedup (inverse du ratio précédent) et ferez un plot de celui-ci

# %% [markdown]
# ## Scénario 1 - version itérative

# %%
''' code du scénario 1 - vous pouvez utiliser plusieurs cellule '''
# En mode debug avec 1 personne, sans UI
debug = Debug(True)
UI=affichage.OpenCV;
file = open_file(petite_grille, debug)  # On ouvre le fichier
X, Y = read_grid_size(file, debug) # On lit la taille
grid = Grille(X, Y, affichage.Aucun, debug)     # On créée l'objet grille
read_obstacles(file, grid, Obstacle, debug)  # On lit et positionne les obstacles
read_personnes(file, grid, Personne, 1, debug) # On lit et positionne une seule personne
print("*"*20)
print("Début de la simulation")
grid.Simulation()

if UI==affichage.OpenCV:
    for image in grid.mapList:
        cv2.imshow("img", createImage(image))
        cv2.waitKey(500) # Wait for 0.5 second
    cv2.destroyAllWindows()
# Out:
# ('Ouverture du fichier', 'maps/map-initial.txt')
# ('Simulation pour une grille:', 10, '*', 10)
# ("Initilisation de l'objet grille",)
# ('obstacle non créé', ['-1', '-1', '-1', '-1'])
# ("Création de l'obstacle (", 1, 1, ') - (', 2, 7, ')')
# ("Création de l'obstacle (", 1, 7, ') - (', 8, 8, ')')
# (2, 'obstacles ont été créés')
# ('Création de la personne qui part de', 2, 2, 'pour aller à', 0, 0)
# ('Création de la personne qui part de', 3, 3, 'pour aller à', 0, 9)
# (2, 'personnes ont été créées')
# ********************
# Début de la simulation
# ('La personne (', 2, 2, ') peut se déplacer sur :', [(3, 2, 1)])
# ('Déplacement de la personne de (', 2, 2, ') à (', 2, 1, ')')
# ('La personne (', 3, 3, ') peut se déplacer sur :', [(8, 2, 3), (8, 3, 4)])
# ('Déplacement de la personne de (', 3, 3, ') à (', 2, 3, ')')
# ('La personne (', 2, 1, ') peut se déplacer sur :', [(2, 1, 1), (2, 2, 0)])
# ('Déplacement de la personne de (', 2, 1, ') à (', 1, 1, ')')
# ('La personne (', 2, 3, ') peut se déplacer sur :', [(7, 2, 4)])
# ('Déplacement de la personne de (', 2, 3, ') à (', 2, 4, ')')
# ('La personne (', 1, 1, ') peut se déplacer sur :', [(1, 0, 1), (1, 1, 0)])
# ('Déplacement de la personne de (', 1, 1, ') à (', 0, 1, ')')
# ('La personne (', 2, 4, ') peut se déplacer sur :', [(6, 2, 5)])
# ('Déplacement de la personne de (', 2, 4, ') à (', 2, 5, ')')
# ('La personne (', 0, 1, ') peut se déplacer sur :', [(0, 0, 0)])
# ('Déplacement de la personne de (', 0, 1, ') à (', 0, 0, ')')
# ('La personne (', 2, 5, ') peut se déplacer sur :', [(5, 2, 6)])
# ('Déplacement de la personne de (', 2, 5, ') à (', 2, 6, ')')
# ('Une personne vient de sortir, il reste', 1, 'personnes')
# ('La personne (', 2, 6, ') peut se déplacer sur :', [(4, 2, 7)])
# ('Déplacement de la personne de (', 2, 6, ') à (', 2, 7, ')')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ...
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ('La personne (', 2, 7, ') peut se déplacer sur :', [])
# ('La personne (', 2, 7, 'ne peut pas se déplacer')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-b0dcdec03913> in <module>
#      10 print("*"*20)
#      11 print("Début de la simulation")
# ---> 12 grid.Simulation()
#      13
#      14 if UI==affichage.OpenCV:
#
# <ipython-input-12-7cc71fabece1> in Simulation(self)
#      69         while len(self.personneList)>0: # il y a encore une personne dans la liste qui peut bouger
#      70             for personne in self.personneList:
# ---> 71                 end, immobile = personne.deplacePersonne(self, self.debug)
#      72                 if end:
#      73                     self.debug.affiche("Une personne vient de sortir, il reste", len(self.personneList), "personnes")
#
# <ipython-input-18-bc617d9acdcf> in deplacePersonne(self, grid, debug)
#      48
#      49         # sinon on recherche les déplacements possibles
# ---> 50         availableMove = self.getAvailableMove(grid)
#      51         debug.affiche("La personne (", self.X, self.Y, ") peut se déplacer sur :", availableMove)
#      52
#
# <ipython-input-18-bc617d9acdcf> in getAvailableMove(self, grid)
#      23                     # on est sur une case adjacente et on est sur la grille
#      24                     if grid.isCellEmpty(x, y): # si la case est vide
# ---> 25                         dist = distance((self.Xsortie, self.Ysortie), (x,y))
#      26                         if (dist<dist_actuel): # on se rappproche
#      27                              depl.append((dist, x, y))
#
# <ipython-input-18-bc617d9acdcf> in distance(X, Y)
#       1 def distance(X, Y):
# ----> 2     return int(np.abs(X[0]-Y[0])+np.abs(X[1]-Y[1]))
#       3
#       4 class Personne():
#       5     def __init__(self, grid, Xinit, Yinit, Xsortie, Ysortie, debug):
#
# KeyboardInterrupt:

# %%
''' plot du temps d'exécution en fonction du nombre de personnes '''

start = time.time()
grid.Simulation(debug)
end = time.time()
duration_i += [end-start]
print("La simulation a duré", duration1[-1], "secondes")
print("Il restait", XXXXX, "personnes immobiles")

# %% [markdown]
# Votre analyse du scénario 1

# %% [markdown]
# ## Scénario 2 - version 1 thread par personne

# %% [markdown]
# ## Scénario 3 - version 1 thread pour 1/4 de la grille

# %% [markdown]
# ## Comparaison des trois approches
#
# <span style="color:red">On attend ici une comparaison argumentée permettant de mettre en évidence les points forts et les points faibles des différentes solutions</span>

# %% [markdown]
# ## Export du notebook dans un fichier python

# %%
import sys,json
import ipyparams

def convertNotebook(notebookPath, modulePath):
    f = open(notebookPath, 'r') #input.ipynb
    j = json.load(f)

    of = open(modulePath, 'w') #output.py

    if j["nbformat"] >=4:
        for i,cell in enumerate(j["cells"]):
            if cell['cell_type']=='code':
                of.write("#cell "+str(i+1)+"\n")
                for line in cell["source"]:
                    of.write(line)
                of.write('\n\n')
    else:
        print("not implemented")

    of.close()

# %%
''' Remarks: it is necessary to put the import code in a separate cell above the call of function.
Otherwise Jupyter will try to run the code before the library is fully loaded,
so the currentNotebook variable is still blank.

Putting the import in its own cell forces it to load before moving to the next cell.
'''
if is_running_from_ipython():
    currentNotebook = ipyparams.notebook_name
    pythonName = currentNotebook.split(".")[0]+".py"
    
    convertNotebook(currentNotebook, pythonName)
